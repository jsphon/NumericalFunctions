# %%
import numba as nb

@nb.jit( nopython=True )
def f(x):
    r=0
    if x>=1:
       return f(0)
    return 0

print( f(1) )
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /home/jon/anaconda/envs/py33/lib/python3.3/site-packages/numba/typeinfer.py in propagate(self, context, typevars)
#      97             try:
# ---> 98                 constrain(context, typevars)
#      99             except TypingError:
#
# /home/jon/anaconda/envs/py33/lib/python3.3/site-packages/numba/typeinfer.py in __call__(self, context, typevars)
#     217         fnty = typevars[self.func].getone()
# --> 218         self.resolve(context, typevars, fnty)
#     219
#
# /home/jon/anaconda/envs/py33/lib/python3.3/site-packages/numba/typeinfer.py in resolve(self, context, typevars, fnty)
#     239             kw_args = dict(zip(kwds, args[n_pos_args:]))
# --> 240             sig = context.resolve_function_type(fnty, pos_args, kw_args)
#     241             if sig is None:
#
# ...
